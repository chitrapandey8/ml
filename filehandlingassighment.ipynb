# %%
with open('sample.txt','r') as file:
    content = file.read()
    print(content)
# Out:
# okok im am writting
# im hello

# %%
with open('sample.txt','r') as file:
    for line in file:
        print(line.strip())
# Out:
# okok im am writting
# im hello

# %%
with open('output.txt','w') as file:
    file.write("heelo im wriittng  ro this file")

# %%
def copy_file():
    with open('sample.txt','r') as file:
        content = file.read()
    with open('destination.txt','w') as file:
        file.write(content)
copy_file()

# %%
def appending_file(text):
    with open('sample.txt','a') as file:
        file.write(text + "\n")
appending_file("this is appended text")

# %%
with open('sample.txt','a') as file:
    file.write("hello im appended\n")
    file.write("hello im appended2\n")

# %%
with open('destination.txt','r') as file:
    content = file.read()
    words = content.split()
    print(len(words))
# Out:
# 6
