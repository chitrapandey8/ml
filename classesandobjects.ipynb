# %%
class car:   #class
    pass

audi=car() #object
bmw=car() 

print(type(audi))
# Out:
# <class '__main__.car'>

# %%
audi.windows=4
print(audi.windows)


print(audi)
print(bmw)
# Out:
# 4
# ...

# %%
dir(audi) ##prints inbult methods
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'windows']

# %%
##instance variable amd method

class Dog:
    ##consturtor
    def __init__(self,name,age): #giving these calues at runtime ##self is keyword self == this
        self.name=name  #__init__ == constructor
        self.age=age

        
 ##create object
dog1=Dog("bruno",2)
print(dog1) ##location of object
print(dog1.name) #for printing name
print(dog1.age)
# Out:
# ...
# bruno
# 2

# %%
class Dog:
    def __init__(self,name, age):
        self.name= name
        self.age= age
    def bark(self): ##methods 
        print(f"{self.name} woof woof")


dog1=Dog("bruno",2)
dog1.bark()
# Out:
# bruno woof woof

# %%
#moding a bank account
##defiine class for bank account

class Bank:
    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance
    def deposit(self,amount):
        self.balance+=amount
        print(f"{amount} deposited new balance is {self.balance}")
    def withdrwa(self,amount):
        if amount>self.balance:
            print("insidb")
        else:
            self.balance-=amount
            print(f"{amount} is withdrwn new balance is {self.balance}")
    def get_balance(self):
         return self.balance

account = Bank("chitranshi",2000)
print(account.get_balance)
# Out:
# <bound method Bank.get_balance of <__main__.Bank object at 0x000001FFEE151160>>

# %%
##inheritance in python 

class car:
    def __init__(self,windows,doors,enginetype):
        self.windows=windows
        self.doors=doors
        self.enginetype=enginetype
        
    def drive(self):
       print(f"the person will drive the {self.enginetype} car") ##enginetype is an attibutr have to use self

# %%
class tesla(car): ##inheroting parent car class
    def __init__(self,windows,doors,enginetype,is_selfdrive):
        super().__init__(windows,doors,enginetype)
        self.isselfdrive=is_selfdrive
    def selfdrive(self):
        print(F"Tesla supports {self.is_selfdrive}")

# %%
carrr = tesla(4,4,"petrol","true")
carrr.windows
carrr.selfdrive()
carrr.drive()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 3
#       1 carrr = tesla(4,4,"petrol","true")
#       2 carrr.windows
# ----> 3 carrr.selfdrive()
#       4 carrr.drive()
#
# Cell In[12], line 6, in tesla.selfdrive(self)
#       5 def selfdrive(self):
# ----> 6     print(F"Tesla supports {self.is_selfdrive}")
#
# AttributeError: 'tesla' object has no attribute 'is_selfdrive'

# %%
##multiple inheritance
class Animal:
    def __init__(self,name):
        self.name=name

    def speak(self):
        print("subclass must implimnt this method")

 ##base clas 2
class pet:
    def __init__(self,owner):
        self.owner=owner

##derived class
class Dog(Animal,pet):
     def __init__(self,name,owner):
         Animal.__init__(self,name)
         pet.__init__(self,owner)

     def speak(self):
         return f"{self.name} say woof"

# %%
dog1=Dog("bruno","chitranshi")
print(dog1.speak())
# Out:
# bruno say woof

# %%
class A:
    def show(self):
        print("this is class A")

class B:
    def show(self):
        print("this is class B")

class C(B, A):
    pass

# %%
classckaobj  = C()
classckaobj.show()
# Out:
# this is class B

# %%
##polymorphismm
##method overriding
class Animal:
    def speak(self):
        return "sound of animal"

 
##drived class 

class Dog(Animal):
    def speak(self):
        return "woof!"
    
class cat(Animal):
    def speak(self):
        return "mewo"  


##function demonstrating polymorphsm

def animal_speak(Animal):
    print(Animal.speak())


dog =Dog()
print(dog.speak())
car = cat()
print(car.speak())
animal_speak(car)
# Out:
# woof!
# mewo
# mewo

# %%
class Dog:
    def speak(self):
        return "woof woof"
    
class Cat:
    def speak(self):
        return "mewo mewo" 


def animal_sound(animal):
    print(animal.speak())

dog1=Dog()
animal_sound(dog1)
# Out:
# woof woof

# %%
##plotymorphism with fucntions and methods

class Shape:
    def area(self):
        return "the area of figure"
    

    ##derived class 1
class reactangle(Shape):
    def __int__(self,widht,height):
        self.width=widht
        self.height=height

    def area(self):
        return self.width*self.height
  
  

  ##derived class 1

class circle(Shape):
    def __init__(self,radius):
        self.radius=radius
    
    def area(self):
        return 3.14*self.radius*self.radius
    

def print_area(Shape):
    print(f"the area of {Shape.area()}")


circle1=circle(4)

print_area(circle1)
# Out:
# the area of 50.24

# %%
from abc import ABC,abstractmethod

##define an abstract class
class vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass

    ##derived class 1

class car(vehicle):
    def start_engine(self):
        return "car engine started"

  ##derived class 2


class Motarcycle(vehicle):
    def start_engine(self):
        return "moter  engine started"
    

def main(vehicle):
    print(vehicle.start_engine())
car=car()

print(car.start_engine())

main(car)
# Out:
# car engine started
# car engine started

# %%
##encapsulationn
##getetr and setter
# public, protected, private

class person:
    def __init__(self,name,age):
        self.name=name
        self.age=age


def get_name(person):
    return person.name        

person= person("chitra",34) 
print(person.name) 

get_name(person)
# Out:
# chitra
# 'chitra'

# %%
class person:
    def __init__(self,name,age,gender):
        self.__name=name
        self.__age=age
        self.gender=gender  ##private variabvle ##pro protctd only one _


def get_name(person):
    return person.name        

person= person("chitra",34,"female") 
print(person.name) 

get_name(person)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 12
#       9     return person.name
#      11 person= person("chitra",34,"female")
# ---> 12 print(person.name)
#      14 get_name(person)
#
# AttributeError: 'person' object has no attribute 'name'

# %%
##dir(person)

class person:
    def __init__(self,name,age,gender):
        self.__name=name
        self.__age=age
        self.gender=gender

def get_name(person):
    return person.name


person1=person("chitra",3,"male")

get_name(person1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 15
#      10     return person.name
#      13 person1=person("chitra",3,"male")
# ---> 15 get_name(person1)
#
# Cell In[50], line 10, in get_name(person)
#       9 def get_name(person):
# ---> 10     return person.name
#
# AttributeError: 'person' object has no attribute 'name'

# %%
class person:
    def __init__(self,name,age,gender):
        self._name=name    ##only it derived class willmbe accsing the priotected avriavble
        self._age=age
        self.gender=gender

class employee(person):
    def __init__(self,name,age,gender):
        super().__init__(name,age,gender)

employeeee = employee("chitra",18,"female")

print(employeeee._name)
# Out:
# chitra

# %%
class person:
    def __init__(self, name, age):
        self.__name=name ##private
        self.__age=age  ##private


#geter method
    def get_name(self):
        return self.__name

    ##setetr method
    def set_name(self):
        self.__name=name   

    def set_age(self,age):
        if age>0:
            self.__age = age
        else:
            print("enter the valid data")

person1 = person("me",18)
print(person1.get_name())
# Out:
# me

# %%
##abstraction
from abc import ABC,abstractmethod


class

# %%
##magic methods 

class person():
    pass 


person1 = person()

dir(person1) ##displyas magic methodss
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
print(person1)

# %%
##basic magic methods and overwritting them

class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age

    def __str__(self):  ##functionality
        return f"{self.name},{self.age}"    


    def __repr__(self):
        return f"personanme {self.name}, age{self.age}"
person1 = Person("chitra",7)
print(person1)        

print(repr(person1))
# Out:
# chitra,7
# personanme chitra, age7

# %%
##operator overloading
##mathematical operation for vectrors
class vector:
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def __add__(self,other):
        return vector(self.x+other.x, self.y+other.y) 
    def __sub__(self,other):
        return vector(self.x-other.x, self.y-other.y) 
    def __mul__(self,other):
        return vector(self.x*other, self.y*other) 
    def __eual__(self,other):
        return self.x==other.x, self.y==other.y 

    def __repr__(self):
        return f"vector({self.x}, {self.y})"
    

v1 = vector(2,3)
v2 = vector(4,5)

print(v1-v2)
print(v1+v2)
print(v1*3)
# Out:
# vector(-2, -2)
# vector(6, 8)
# vector(6, 9)

# %%
##custom exception raise and throw an exception

class Error(Exception):
    pass

class dobException(Error):
    pass

# %%
year=int(input("enter dob"))
age=2024-year

try:
    if age<=30 and age>=20:
        print("valid")
    else:
        raise dobException    

except dobException:
    print("sorry ur age shold be 20")
# Out:
# sorry ur age shold be 20

# %%
def divison(a,b):
    try:
        result=a/b
        return result
    except ZeroDivisionError as ex:
        print(ex)
        print("not defined")
    

print(divison(2,3))
print(divison(2,0))
# Out:
# 0.6666666666666666
# division by zero
# not defined
# None

# %%
def file_read():
    try:
        file=open('data.txt')
        content=file.read()
        print(content)
    except FileNotFoundError:
        print()    
    except Exception as ex:
        print(ex)

# %%
n = int(input("enter no of rows"))
for i in range(1,n+1,1):
            print("*"*(n-i+1))
# Out:
# *******
# ******
# *****
# ****
# ***
# **
# *

# %%
for i in range(1,8,1):
    print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******

# %%
# list = [1,2,3,4,5]
# sum = 0
# for x in list:
#     sum += x
    
# print(sum)    


# arr = input().split()

# for i in range(len(arr)):
#     arr[i]=int(arr[i])

# print(arr)  


# arr = input().split()
# n = int(input("enter no of rows"))

# for i in range(n):
#     arr1 = input().split()



row = 3
a = []
for i in range(row):
    b = list(map(int,input().split()))
    a.append(b)
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 28
#      26 a = []
#      27 for i in range(row):
# ---> 28     b = list(map(int,input().split()))
#      29     a.append(b)
#      30 print(a)
#
# TypeError: 'list' object is not callable

# %%
row = 3
a = []
for i in range(row):
    b = list(map(int,input().split()))
    a.append(b)
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       2 a = []
#       3 for i in range(row):
# ----> 4     b = list(map(int,input().split()))
#       5     a.append(b)
#       6 print(a)
#
# TypeError: 'list' object is not callable

# %%
# arr = input().split()

# for i in range(len(arr)):
#   arr[i]=int(arr[i])


# [
#   [1,2,3]
#   [1,2,3]
#   [1,2,3]
# ] 

row = 3
a = []
for i in range(row):
  b = list(map(int,input().split()))
  a.append(b)
print(a)
# Out:
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]
