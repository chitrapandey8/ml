# %%
with open('example.txt','r') as file:
    content = file.read()
    print(content)
# Out:
# hello

# %%
with open('example.txt','r') as file:
    for line in file:
        print(line.strip()) #strip removes new line cgaraecter
# Out:
# hello
# im chitranshi

# %%
with open('example.txt','w') as file:
    file.write("hello wolr")
    file.write("im ok")

# %%
#writting without overwriting
with open('example.txt','w') as file:
    file.write("append takiing place")

# %%
lines=["i","i"]
with open('example.

# %%
data = b'\x00\x01\x02\x03'
with open('example.bin','wb') as file:
    file.write(data)

# %%
with open('example.bin','rb') as file:
    content = file.read()
    print(content)
# Out:
# b'\x00\x01\x02\x03'

# %%
with open('example.txt','r') as source_file:

# %%
#writing and reading a file
with open('example.txt','w+') as file:
    file.write("hello world\n")
    file.write("this is new line")

    #move the file cursor to the beigngngi

    file.seek(0)

    #read the content of the file
    content = file.read()
    print(content)
# Out:
# hello world
# this is new line

# %%
#create a new dicactory
import os
new_dir = "package"
os.mkdir(new_dir)
print(f"dic '(new_dir)' cretae")
# Out:
# dic '(new_dir)' cretae

# %%
items = os.listdir('.')
print(items)
# Out:
# ['.ipynb_checkpoints', 'example.bin', 'example.txt', 'moduleandpackages.ipynb', 'package', 'Untitled.ipynb']

# %%
#joining paths realayive path deta h idhar tak kese aaye 
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# C:\ML\folder\file.txt

# %%
path = 'example.txt'
if os.path.exists(path):
    print(f"the path exits")
else:
    print(f"doesnot")
# Out:
# the path exits

# %%
#getiing the absolutte path
relative_path = 'example.txt'
absolute_path=os.path.abspath(relative_path)
print(absolute_path)
# Out:
# C:\ML\example.txt

# %%
#modules and packages
#importing
import math 
math.sqrt(16)
# Out:
# 4.0

# %%
##importing function
from math import sqrt,pi
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
##ACCCESING ALL FUCNTIONS
from math import *
print(pi)
# Out:
# 3.141592653589793

# %%
from package.maths import addition
addition(2,3)
# Out:
# 5

# %%
# %run package/test.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File C:\ML\package\test.py:2
#       1 from package.maths import *
# ----> 2 print(additon(2,3))
#
# NameError: name 'additon' is not defined
