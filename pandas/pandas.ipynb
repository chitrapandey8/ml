# %%
##pandas used for data  analysis and c;eaning


pip install pandas
# Out:
#   Cell In[2], line 4
#     pip install pandas
#         ^
# SyntaxError: invalid syntax

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 1.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.0/9.9 MB 1.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/9.9 MB 1.7 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.7 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/9.9 MB 1.8 MB/s eta 0:00:05
#    --------- ------------------------------ 2.4/9.9 MB 1.7 MB/s eta 0:00:05
#    --------- ------------------------------ 2.4/9.9 MB 1.7 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.6/9.9 MB 1.4 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.9/9.9 MB 1.3 MB/s eta 0:00:06
#    ------------ --------------------------- 3.1/9.9 MB 1.4 MB/s eta 0:00:05
# ...

# %%
import pandas as pd

# %%
##pandas ke do datastructures hote h ek series(1D) and dataframes(2D)--
#pandas is a libarary used for data maipulation , cleaing , analysis and transfromation

# %%
##series 

import pandas as pd

data  = {'a':12}
series = pd.Series(data,)
print(series)
# Out:
# a    12
# dtype: int64

# %%
data = {'a':1,'b':2,'c':3}
series = pd.Series(data)
print(series)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = [10,20,30]
index = [1,2,3]
pd.Series(data,index)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %%
##datraframes

data ={
    'name':['chitra','sania','nuikhi'],
    'age':[25,34,45],
    'city':['banglore','delhit','texas']
}
df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#      name  age      city
# 0  chitra   25  banglore
# 1   sania   34    delhit
# 2  nuikhi   45     texas
# <class 'pandas.DataFrame'>

# %%
##create a dat frmaer from a list of disctotires
##DATAFRAMES------ye 2D table hoti hai,sql jaise table
# 0,1,2 row ka index hota hai name,age city column haihar columm ka alga type ho sakta hai


data = [
    {'name':'chitanshi','age':34,'city':'delhi'},
    {'name':'chita','age':14,'city':'up'},
    {'name':'chiti','age':40,'city':'luicknow'},

]

fd = pd.DataFrame(data)
print(fd)

print(fd['name']) #name ka pura column agaya
#3row accesing
#fd.iloc[0]
fd.iloc[1:3]['age']  #----row slicing
# Out:
#         name  age      city
# 0  chitanshi   34     delhi
# 1      chita   14        up
# 2      chiti   40  luicknow
# 0    chitanshi
# 1        chita
# 2        chiti
# Name: name, dtype: str
# 1    14
# 2    40
# Name: age, dtype: int64

# %%
##important properties of datafrmaes
#df.shape(row,columns) -- 
#df.column ---- column names
#df.head -- first five rows
#df.tail --last 5 rows
#column accesing

# %%
#for csv file
df = pd.read_csv('Students data.csv')
df.head(5) ##for first five row
# Out:
#      ID class  gender  race    GPA  Algebra  Calculus1  Calculus2  Statistics  \
# 0  1141     A    male     1  73.47       64         81         87          60
# 1  1142     A  female     1  71.22       57         50         51          51
# 2  1143     A  female     2  74.56       47         48         71          60
# 3  1144     A  female     1  72.89       46         72         38          60
# 4  1145     A  female     1  70.11       49         45         63          60
#
#    Probability  Measure  Functional_analysis from1 from2 from3  from4  y
# 0           74       71                   60     A     A     A      3  0
# 1           55       62                   61     B     A     A      2  0
# 2           61       68                   64     C     A     A      0  1
# 3           29       54                   51     D     A     A      0  0
# 4           66       66                   61     E     A     A      0  0

# %%
##accesing data from dtaa frames
data
# Out:
# [{'name': 'chitanshi', 'age': 34, 'city': 'delhi'},
#  {'name': 'chita', 'age': 14, 'city': 'up'},
#  {'name': 'chiti', 'age': 40, 'city': 'luicknow'}]

# %%
fd
# Out:
#         name  age      city
# 0  chitanshi   34     delhi
# 1      chita   14        up
# 2      chiti   40  luicknow

# %%
print(type(fd))
# Out:
# <class 'pandas.DataFrame'>

# %%
fd.iloc[0] ##zeroth row dega
# Out:
# name    chitanshi
# age            34
# city        delhi
# Name: 0, dtype: object

# %%
fd['name']
##type(fd['name'])
# Out:
# 0    chitanshi
# 1        chita
# 2        chiti
# Name: name, dtype: str

# %%
fd.iloc[1]['name'] ##zero row ka name dedo
# Out:
# 'chita'

# %%
fd.iloc[0:3]['name']
# Out:
# 0    chitanshi
# 1        chita
# 2        chiti
# Name: name, dtype: str

# %%
fd.iloc[0][1:2]
# Out:
# age    34
# Name: 0, dtype: object

# %%
fd
# Out:
#         name  age      city
# 0  chitanshi   34     delhi
# 1      chita   14        up
# 2      chiti   40  luicknow

# %%
##accesing a specified index

fd.at[1,'age'] ##roe ka index and column ka name
b
# Out:
# np.int64(14)

# %%
fd.iat[2,2] ##row index column index
# Out:
# 'luicknow'

# %%
fd
# Out:
#         name  age      city
# 0  chitanshi   34     delhi
# 1      chita   14        up
# 2      chiti   40  luicknow

# %%
#3data manipulation with dataframes

fd['salary'] = [5000,6000,70000] ##adding a column
fd
# Out:
#         name  age      city  salary
# 0  chitanshi   34     delhi    5000
# 1      chita   14        up    6000
# 2      chiti   40  luicknow   70000

# %%
##remove a colun
fd.drop('salary',axis=1,inplace=True)  ##for checking column wise coz in deafultit chekcs row wise
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 2
#       1 ##remove a colun
# ----> 2 fd.drop('salary',axis=1,inplace=True)  ##for checking column wise coz in deafultit chekcs row wise
#
# File c:\Users\Chitranshi Pandey\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
# ...

# %%
##add age to the cvolumm
fd['age']=fd['age']+1

fd
# Out:
#         name  age      city
# 0  chitanshi   36     delhi
# 1      chita   16        up
# 2      chiti   42  luicknow

# %%
df.drop(0,inplace=True) ##the changes are not permannent to make it permannt we use inplace = true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.drop(0,inplace=True) ##the changes are not permannent to make it permannt we use inplace = true
#
# NameError: name 'df' is not defined

# %%
fd
# Out:
#         name  age      city
# 0  chitanshi   35     delhi
# 1      chita   15        up
# 2      chiti   41  luicknow

# %%
##daat manipulation ans anualysis with pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('Studentsdata.csv')
print(df)

df = pd.read_csv("xnmbs")
print(df)
# Out:
#        ID class  gender  race    GPA  Algebra  Calculus1  Calculus2  \
# 0    1141     A    male     1  73.47       64         81         87
# 1    1142     A  female     1  71.22       57         50         51
# 2    1143     A  female     2  74.56       47         48         71
# 3    1144     A  female     1  72.89       46         72         38
# 4    1145     A  female     1  70.11       49         45         63
# ..    ...   ...     ...   ...    ...      ...        ...        ...
# 100  1241     A  female     1  88.34       87         83         92
# 101  1242     B    male     1  89.84       98         77         95
# 102  1243     B    male     1  88.82       83         80         91
# 103  1244     A    male     1  86.60       92         82         91
# 104  1245     A    male     1  93.71       93         97         99
#
#      Statistics  Probability  Measure  Functional_analysis from1 from2 from3  \
# ...

# %%
df.tail(5) ## last ki panch row
# Out:
#        ID class  gender  race    GPA  Algebra  Calculus1  Calculus2  \
# 100  1241     A  female     1  88.34       87         83         92
# 101  1242     B    male     1  89.84       98         77         95
# 102  1243     B    male     1  88.82       83         80         91
# 103  1244     A    male     1  86.60       92         82         91
# 104  1245     A    male     1  93.71       93         97         99
#
#      Statistics  Probability  Measure  Functional_analysis from1 from2 from3  \
# 100          98           93       86                   90     M     B     A
# 101          98           96       88                  100     A     B     A
# 102          98           93       95                   71     T     B     A
# 103          99           94       82                   78     S     B     A
# 104         100           97       90                   90     K     B     A
#
#      from4  y
# 100      0  1
# 101      0  1
# 102      0  2
# 103      0  2
# 104      0  2

# %%
df.describe() ##statical data deta hai --min,mean,count,max, avg data ka short report card
# Out:
#                 ID        race         GPA     Algebra   Calculus1  \
# count   105.000000  105.000000  105.000000  105.000000  105.000000
# mean   1193.000000    1.790476   82.957048   76.057143   71.961905
# std      30.454885    1.673867    6.053187   11.722618   12.197039
# min    1141.000000    1.000000   63.490000   46.000000   38.000000
# 25%    1167.000000    1.000000   79.340000   67.000000   64.000000
# 50%    1193.000000    1.000000   84.110000   76.000000   73.000000
# 75%    1219.000000    1.000000   87.300000   84.000000   80.000000
# max    1245.000000    7.000000   93.710000   98.000000  100.000000
#
#         Calculus2  Statistics  Probability     Measure  Functional_analysis  \
# count  105.000000  105.000000   105.000000  105.000000           105.000000
# mean    78.942857   85.133333    83.876190   80.761905            75.323810
# std     14.997326   10.269509    10.514363   10.296119            13.003324
# ...

# %%
df.dtypes  #--dataframe ke har column ka data type batat hai
# Out:
# ID                       int64
# class                      str
# gender                     str
# race                     int64
# GPA                    float64
# Algebra                  int64
# Calculus1                int64
# Calculus2                int64
# Statistics               int64
# Probability              int64
# Measure                  int64
# Functional_analysis      int64
# from1                      str
# from2                      str
# from3                      str
# from4                    int64
# y                        int64
# dtype: object

# %%
##handling missing value -- 
#df.isnull()--dataframe maia jaha bbi missing h wahaa true deta hai
#df.isnull().any() --agar coulumn mai kam se kam ek bhi missing value h toh true or bilkul missing nhi h toh false
df.isnull().any(axis=1)  #axxis = 0  mtln column wise check karna or axis = 1 mtln row wise chekc karna default bhi axis = 0 hota hai
##df.isnull().sum() #3true ko one manta hai or false ko zero or uska sum kr deta hai
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 100    False
# 101    False
# 102    False
# 103    False
# 104    False
# Length: 105, dtype: bool

# %%
df.fillna(1) ## jaha bhi mising ya naa h waha fill kardo in this cas ejha bhi naan h eaha 1 daaldo
# Out:
#        ID class  gender  race    GPA  Algebra  Calculus1  Calculus2  \
# 0    1141     A    male     1  73.47       64         81         87
# 1    1142     A  female     1  71.22       57         50         51
# 2    1143     A  female     2  74.56       47         48         71
# 3    1144     A  female     1  72.89       46         72         38
# 4    1145     A  female     1  70.11       49         45         63
# ..    ...   ...     ...   ...    ...      ...        ...        ...
# 100  1241     A  female     1  88.34       87         83         92
# 101  1242     B    male     1  89.84       98         77         95
# 102  1243     B    male     1  88.82       83         80         91
# 103  1244     A    male     1  86.60       92         82         91
# 104  1245     A    male     1  93.71       93         97         99
#
#      Statistics  Probability  Measure  Functional_analysis from1 from2 from3  \
# ...

# %%
##filing misisn values with mean of the columns--chatgpt se padhana
df['sales_fill'] = df['Algebra'].fillna(df['Algebra'].mean()) ##algebra mai jaop or jaha bhi null h waha mean daldo or ek naya column bnrah data dalne ke liye
df
# Out:
#        ID class  gender  race    GPA  Algebra  Calculus1  Calculus2  \
# 0    1141     A    male     1  73.47       64         81         87
# 1    1142     A  female     1  71.22       57         50         51
# 2    1143     A  female     2  74.56       47         48         71
# 3    1144     A  female     1  72.89       46         72         38
# 4    1145     A  female     1  70.11       49         45         63
# ..    ...   ...     ...   ...    ...      ...        ...        ...
# 100  1241     A  female     1  88.34       87         83         92
# 101  1242     B    male     1  89.84       98         77         95
# 102  1243     B    male     1  88.82       83         80         91
# 103  1244     A    male     1  86.60       92         82         91
# 104  1245     A    male     1  93.71       93         97         99
#
#      Statistics  Probability  Measure  Functional_analysis from1 from2 from3  \
# ...

# %%
##remainh coloums --pandas ka function h jo row and coloumn ka name change karta hai purana name dete hai or name dete hai
df=df.rename(columns={'Algebra':'Awe'}) 
df
# Out:
#        ID class  gender  race    GPA  Awe  Calculus1  Calculus2  Statistics  \
# 0    1141     A    male     1  73.47   64         81         87          60
# 1    1142     A  female     1  71.22   57         50         51          51
# 2    1143     A  female     2  74.56   47         48         71          60
# 3    1144     A  female     1  72.89   46         72         38          60
# 4    1145     A  female     1  70.11   49         45         63          60
# ..    ...   ...     ...   ...    ...  ...        ...        ...         ...
# 100  1241     A  female     1  88.34   87         83         92          98
# 101  1242     B    male     1  89.84   98         77         95          98
# 102  1243     B    male     1  88.82   83         80         91          98
# 103  1244     A    male     1  86.60   92         82         91          99
# 104  1245     A    male     1  93.71   93         97         99         100
#
# ...

# %%
##change datatypes
df['class_new'] = df['gender'].fillna(df['gender'].mean()).astype(int) ## ye female ka 0 leta h or male ka 1 or uska mean nikale ga or gendermai jaha bhi na hoga waha fill kar dega as int decimal ko int bana rahaa
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 ##change datatypes
# ----> 2 df['class_new'] = df['gender'].fillna(df['gender'].mean()).astype(int)
#
# File c:\Users\Chitranshi Pandey\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\Chitranshi Pandey\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\series.py:8113, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
# ...

# %% [markdown]
# ##expression in dataframes
# df['New_value'] = df['race'].apply(lambda x:x*2)
# df.head(5)

# %%
##group da data on the basic of hign and mean of close
grouped_mean = df.groupby('gender')['Calculus1'].mean() ## gender ke basis ke gruops mai divide ,Ab har group ke andar sirf Calculus1 column select kar rahe ho.Ab har group ke Calculus1 marks ka average nikal rahe ho.
print(grouped_mean)
# Out:
# gender
# female    70.529412
# male      74.594595
# Name: Calculus1, dtype: float64

# %%
df['New_value'] = df['race'].apply(lambda x:x*2) ##race column select karke, apply mtln column ke har ek vakue par function lagagane  or naye column mai stor hoga

# %%
####multiple groups --------komse colums group krne h ---kiske basis pe
# grouped_mean1 = df.groupby(['gender','race'])['Statistics'].sum() 
# print(grouped_mean1)
grouped_mean1 = df.groupby(['gender','race'])['Statistics'].agg(['mean','sum']) ##gander or race coulmn ke basis pe group karra h or un gruops ke liye statistics select kiya yaah do cheez nikal rha aha hai mean and sum
print(grouped_mean1)
# Out:
#                   mean   sum
# gender race
# female 1     86.500000  4844
#        2     60.000000    60
#        3     90.000000   180
#        4     83.500000   167
#        5     66.666667   200
#        6     84.000000   168
#        7     87.000000   174
# male   1     86.360000  2159
#        2     90.000000   180
#        3     78.250000   313
#        4     76.000000   152
#        5     87.000000    87
#        7     85.000000   255

# %%
## merging and joing dataframes
df1=pd.DataFrame({'key':['A','B','C'], 'vales1':[1,2,3]})
df2=pd.DataFrame({'key':['A','B','D'], 'vales1':[4,5,6]})

# %%
pd.merge(df1,df2,on="key",how="inner")
# Out:
#   key  vales1_x  vales1_y
# 0   A         1         4
# 1   B         2         5
