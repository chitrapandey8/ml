# %%
import logging

logging.basicConfig(level=logging.DEBUG)

##log messages----default levels---debug,info,warning,error,critical
logging.debug("this is a debug message")
logging.info("thiss is ingo messgae ")
logging.warning(" this is warning messgae")
logging.error("this is error ")
logging.critical(" critical")
# Out:
# DEBUG:root:this is a debug message
# INFO:root:thiss is ingo messgae
# WARNING:root: this is warning messgae
# ERROR:root:this is error
# CRITICAL:root: critical

# %%
##configuring logging
logging.basicConfig(
   filename='app.log',filemode='w', level=logging.DEBUG,format="%(asctime)s-%(name)s-%(levelname)s-%(message)s",datefmt='%y-%m-%d %H:%M:%S',force=True)

logging.debug("this is a debug message")
logging.info("thiss is ingo messgae ")
logging.warning(" this is warning messgae")
logging.error("this is error ")
logging.critical(" critical")

# %%
import logging

# %%
logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

logger2 = logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

logging.basicConfig(
   filename='app.log',filemode='w', level=logging.DEBUG,format="%(asctime)s-%(name)s-%(levelname)s-%(message)s",datefmt='%y-%m-%d %H:%M:%S',force=True)

# %%
logger1.debug("msxmsxmsxmsmx")
logger2.warning("dmcnd")
