# %%
addition = lambda a,b:a+b
print(addition(2,3))
# Out:
# 5

# %%
even = lambda num:num%2==0
print(even(4))
# Out:
# True

# %%
addition = lambda a,b,c:a+b+c
addition(1,2,3)
# Out:
# 6

# %%
num = [1,2,3,4,5,6]
def square(number):
    return number**2


square(2)
# Out:
# 4

# %%
#map  function
numbers = [1,2,3,4,5,6]
list(map(square, numbers))
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
##lambda with map
numbers = [1,2,3,4,5,6]
list(map(lambda x:x*x,numbers))
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
num1=[1,2,3]
num2=[4,5,6]

add=list(map(lambda x,y:x+y, num1, num2))
print(add)
# Out:
# [5, 7, 9]

# %%
words=['apple','banan']
upperer=list(map(str.upper,words))
print(upperer)
# Out:
# ['APPLE', 'BANAN']

# %%
def get_name(person):
    return person['name']

    people=[{
    'name':'heelo'}]

    acha=list(map(get_name,people))
    print(acha)

# %%
##filterrr
##first para as fucntiom and second is list
# %run test.py
# Out:
# 5
